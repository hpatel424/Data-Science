# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
data = pd.read_csv('/content/purchase_data (1).csv')
data
# Out:
#         User_ID Product_ID Gender    Age  Occupation City_Category  \
# 0       1000001  P00069042      F   0-17        10.0             A
# 1       1000001  P00248942      F   0-17        10.0             A
# 2       1000001  P00087842      F   0-17        10.0             A
# 3       1000001  P00085442      F   0-17        10.0             A
# 4       1000002  P00285442      M    55+        16.0             C
# ...         ...        ...    ...    ...         ...           ...
# 263010  1004473  P00041942      M  36-45         1.0             B
# 263011  1004473  P00115142      M  36-45         1.0             B
# 263012  1004473  P00188442      M  36-45         1.0             B
# 263013  1004473  P00119442      M  36-45         1.0             B
# 263014       10        NaN    NaN    NaN         NaN           NaN
#
#        Stay_In_Current_City_Years  Marital_Status  Product_Category_1  \
# 0                               2             0.0                 3.0
# ...

# %%
#EDA -- Exploratory Data Analysis
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 263015 entries, 0 to 263014
# Data columns (total 12 columns):
#  #   Column                      Non-Null Count   Dtype
# ---  ------                      --------------   -----
#  0   User_ID                     263015 non-null  int64
#  1   Product_ID                  263014 non-null  object
#  2   Gender                      263014 non-null  object
#  3   Age                         263014 non-null  object
#  4   Occupation                  263014 non-null  float64
#  5   City_Category               263014 non-null  object
#  6   Stay_In_Current_City_Years  263014 non-null  object
#  7   Marital_Status              263014 non-null  float64
#  8   Product_Category_1          263014 non-null  float64
#  9   Product_Category_2          181501 non-null  float64
#  10  Product_Category_3          80582 non-null   float64
#  11  Purchase                    263014 non-null  float64
# dtypes: float64(6), int64(1), object(5)
# ...

# %%
data['Stay_In_Current_City_Years'].unique()
# Out:
# array(['2', '4+', '3', '1', '0', nan], dtype=object)

# %%
data['Stay_In_Current_City_Years'] = pd.to_numeric(data['Stay_In_Current_City_Years'],errors='coerce')

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 263015 entries, 0 to 263014
# Data columns (total 12 columns):
#  #   Column                      Non-Null Count   Dtype
# ---  ------                      --------------   -----
#  0   User_ID                     263015 non-null  int64
#  1   Product_ID                  263014 non-null  object
#  2   Gender                      263014 non-null  object
#  3   Age                         263014 non-null  object
#  4   Occupation                  263014 non-null  float64
#  5   City_Category               263014 non-null  object
#  6   Stay_In_Current_City_Years  222349 non-null  float64
#  7   Marital_Status              263014 non-null  float64
#  8   Product_Category_1          263014 non-null  float64
#  9   Product_Category_2          181501 non-null  float64
#  10  Product_Category_3          80582 non-null   float64
#  11  Purchase                    263014 non-null  float64
# dtypes: float64(7), int64(1), object(4)
# ...

# %%
data['Stay_In_Current_City_Years'].unique()
# Out:
# array([ 2., nan,  3.,  1.,  0.])

# %%
data['Age'].value_counts()
# Out:
# Age
# 0-17       7064
# 55+       10321
# 51-55     18509
# 46-50     21619
# 18-25     48193
# 36-45     52396
# 26-35    104912
# Name: count, dtype: int64

# %%
data['Age'].unique()
# Out:
# array(['0-17', '55+', '26-35', '46-50', '51-55', '36-45', '18-25', nan],
#       dtype=object)

# %%
data.isnull().sum()
# Out:
# User_ID                            0
# Product_ID                         1
# Gender                             1
# Age                                1
# Occupation                         1
# City_Category                      1
# Stay_In_Current_City_Years     40666
# Marital_Status                     1
# Product_Category_1                 1
# Product_Category_2             81514
# Product_Category_3            182433
# Purchase                           1
# dtype: int64

# %%
data['Product_Category_2'].fillna(0,inplace=True)
data['Product_Category_3'].fillna(0,inplace=True)
# Out:
# /tmp/ipython-input-731683015.py:1: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   data['Product_Category_2'].fillna(0,inplace=True)
# /tmp/ipython-input-731683015.py:2: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# ...

# %%
data.isnull().sum()
# Out:
# User_ID                           0
# Product_ID                        1
# Gender                            1
# Age                               1
# Occupation                        1
# City_Category                     1
# Stay_In_Current_City_Years    40666
# Marital_Status                    1
# Product_Category_1                1
# Product_Category_2                0
# Product_Category_3                0
# Purchase                          1
# dtype: int64

# %%
data.dropna(inplace=True)

# %%
data.isnull().sum()
# Out:
# User_ID                       0
# Product_ID                    0
# Gender                        0
# Age                           0
# Occupation                    0
# City_Category                 0
# Stay_In_Current_City_Years    0
# Marital_Status                0
# Product_Category_1            0
# Product_Category_2            0
# Product_Category_3            0
# Purchase                      0
# dtype: int64

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 222349 entries, 0 to 263013
# Data columns (total 12 columns):
#  #   Column                      Non-Null Count   Dtype
# ---  ------                      --------------   -----
#  0   User_ID                     222349 non-null  int64
#  1   Product_ID                  222349 non-null  object
#  2   Gender                      222349 non-null  object
#  3   Age                         222349 non-null  object
#  4   Occupation                  222349 non-null  float64
#  5   City_Category               222349 non-null  object
#  6   Stay_In_Current_City_Years  222349 non-null  float64
#  7   Marital_Status              222349 non-null  float64
#  8   Product_Category_1          222349 non-null  float64
#  9   Product_Category_2          222349 non-null  float64
#  10  Product_Category_3          222349 non-null  float64
#  11  Purchase                    222349 non-null  float64
# dtypes: float64(7), int64(1), object(4)
# ...

# %%
from sklearn.preprocessing import LabelEncoder

label_mappings = {}

for i in data.columns:
  if data[i].dtype == 'object':
    le = LabelEncoder()
    data[i]=le.fit_transform(data[i])
    label_mappings[i]=dict(zip(le.classes_, le.transform(le.classes_)))
for column,mapping in label_mappings.items():
  print(f'Mapping for {column}:{mapping}')
# Out:
# Mapping for Product_ID:{'P00000142': np.int64(0), 'P00000242': np.int64(1), 'P00000342': np.int64(2), 'P00000442': np.int64(3), 'P00000542': np.int64(4), 'P00000642': np.int64(5), 'P00000742': np.int64(6), 'P00000842': np.int64(7), 'P00000942': np.int64(8), 'P00001042': np.int64(9), 'P00001142': np.int64(10), 'P00001242': np.int64(11), 'P00001342': np.int64(12), 'P00001442': np.int64(13), 'P00001542': np.int64(14), 'P00001642': np.int64(15), 'P00001742': np.int64(16), 'P00001842': np.int64(17), 'P00001942': np.int64(18), 'P00002042': np.int64(19), 'P00002142': np.int64(20), 'P00002242': np.int64(21), 'P00002342': np.int64(22), 'P00002442': np.int64(23), 'P00002542': np.int64(24), 'P00002642': np.int64(25), 'P00002742': np.int64(26), 'P00002842': np.int64(27), 'P00002942': np.int64(28), 'P00003042': np.int64(29), 'P00003142': np.int64(30), 'P00003242': np.int64(31), 'P00003342': np.int64(32), 'P00003442': np.int64(33), 'P00003542': np.int64(34), 'P00003642': np.int64(35), 'P00003742':
# ...

# %%
data
# Out:
#         User_ID  Product_ID  Gender  Age  Occupation  City_Category  \
# 0       1000001         640       0    0        10.0              0
# 1       1000001        2282       0    0        10.0              0
# 2       1000001         805       0    0        10.0              0
# 3       1000001         781       0    0        10.0              0
# 5       1000003        1751       1    2        15.0              0
# ...         ...         ...     ...  ...         ...            ...
# 263009  1004473        2736       1    3         1.0              1
# 263010  1004473         401       1    3         1.0              1
# 263011  1004473        1004       1    3         1.0              1
# 263012  1004473        1700       1    3         1.0              1
# 263013  1004473        1047       1    3         1.0              1
#
#         Stay_In_Current_City_Years  Marital_Status  Product_Category_1  \
# 0                              2.0             0.0                 3.0
# ...

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 222349 entries, 0 to 263013
# Data columns (total 12 columns):
#  #   Column                      Non-Null Count   Dtype
# ---  ------                      --------------   -----
#  0   User_ID                     222349 non-null  int64
#  1   Product_ID                  222349 non-null  int64
#  2   Gender                      222349 non-null  int64
#  3   Age                         222349 non-null  int64
#  4   Occupation                  222349 non-null  float64
#  5   City_Category               222349 non-null  int64
#  6   Stay_In_Current_City_Years  222349 non-null  float64
#  7   Marital_Status              222349 non-null  float64
#  8   Product_Category_1          222349 non-null  float64
#  9   Product_Category_2          222349 non-null  float64
#  10  Product_Category_3          222349 non-null  float64
#  11  Purchase                    222349 non-null  float64
# dtypes: float64(7), int64(5)
# memory usage: 22.1 MB

# %%
#Statistic analysis
#Steps perform hypothesis Testing:
#1. Data collection
#2. preparing samples
#3. creating two hypothesis(null, alternate)
#4. applying the appropriate test (based on requirement)
#5. if p-value < 0.05 reject of null hypothesis
#    if p-value > 0.05 fail to reject null hypothesis

# %%
#a. It was observed that the average purchase made by men of the age 18-25 was 10000. Is it still the same?

newData = data[(data['Age']==1) & data['Gender']==1]
newData
# Out:
#         User_ID  Product_ID  Gender  Age  Occupation  City_Category  \
# 97      1000021        2004       1    1        16.0              1
# 220     1000039        2574       1    1         4.0              1
# 221     1000039        3228       1    1         4.0              1
# 300     1000052        1320       1    1         4.0              2
# 301     1000052           5       1    1         4.0              2
# ...         ...         ...     ...  ...         ...            ...
# 262767  1004446        1298       1    1        18.0              1
# 262951  1004465        2850       1    1         4.0              0
# 262952  1004465        1283       1    1         4.0              0
# 262953  1004465        2707       1    1         4.0              0
# 262954  1004465        1409       1    1         4.0              0
#
#         Stay_In_Current_City_Years  Marital_Status  Product_Category_1  \
# 97                             0.0             0.0                 3.0
# ...

# %%
newData['Purchase'].mean()
# Out:
# np.float64(9466.768918692373)

# %%
sample = newData.sample(3600,random_state=5)
sample
# Out:
#         User_ID  Product_ID  Gender  Age  Occupation  City_Category  \
# 190087  1005367         102       1    1         4.0              0
# 12234   1001842          50       1    1         4.0              1
# 50865   1001764        2079       1    1         0.0              1
# 82254   1000714        3265       1    1         4.0              1
# 203050  1001329        3105       1    1        14.0              1
# ...         ...         ...     ...  ...         ...            ...
# 156647  1000192         535       1    1         1.0              1
# 67977   1004401        1772       1    1         4.0              0
# 156458  1000163         569       1    1         4.0              0
# 255089  1003391        1250       1    1         4.0              0
# 929     1000163        1762       1    1         4.0              0
#
#         Stay_In_Current_City_Years  Marital_Status  Product_Category_1  \
# 190087                         1.0             0.0                 1.0
# ...

# %%
from scipy.stats import ttest_1samp
alternateMean = 10000
t_stat, p_value = ttest_1samp(sample['Purchase'],alternateMean)
print(t_stat,p_value)
# Out:
# -4.894716313857535 1.0276926610435886e-06

# %%
#b. It was observed that percentage of women that spend more then 10000 was 35%. Is it still the same?
#null hypo = proportion is 35%
#alternate hypo = proportion is not 35%

ndata = data[(data['Purchase'])>10000]
ndata
# Out:
#         User_ID  Product_ID  Gender  Age  Occupation  City_Category  \
# 1       1000001        2282       0    0        10.0              0
# 5       1000003        1751       1    2        15.0              0
# 6       1000004        1668       1    4         7.0              1
# 7       1000004        3180       1    4         7.0              1
# 8       1000004        3448       1    4         7.0              1
# ...         ...         ...     ...  ...         ...            ...
# 262997  1004472        2411       0    4        16.0              1
# 263001  1004472        1901       0    4        16.0              1
# 263002  1004472        1649       0    4        16.0              1
# 263003  1004472        3176       0    4        16.0              1
# 263011  1004473        1004       1    3         1.0              1
#
#         Stay_In_Current_City_Years  Marital_Status  Product_Category_1  \
# 1                              2.0             0.0                 1.0
# ...

# %%
ndata['Gender'].value_counts()
# Out:
# Gender
# 1    60887
# 0    16142
# Name: count, dtype: int64

# %%
#Number of women in the sample
count = ndata['Gender'].value_counts()[0]

#Number of observations
nobs = len(ndata['Gender'])

#hypothesised value
p0 = 0.35

count,nobs,p0
# Out:
# (np.int64(16142), 77029, 0.35)

# %%
16142/77029
# Out:
# 0.20955743940593802

# %%
from statsmodels.stats.proportion import proportions_ztest
z_stat, p_value = proportions_ztest(count = count, nobs = nobs, value = p0)
print(z_stat,p_value)
# Out:
# -95.7721350421428 0.0

# %%
# Out:
# -95.7721350421428 0.0
